# %%
作業1:
    
1. 你選的這組資料為何重要 (dataset: amazon data reviews)
    這組dataset收集了客戶端對於產品的意見，可以由這些data找出未來新產品及目前產品改善的方向。而且還可以從各項分類了解用戶對於各項商品喜好程度，是很重要的市場調查。
2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
    data的提供來源是從amazon官網上的reviews擷取出來的，將近3000組用戶提供的意見(ratings, review時間, 產品feedback)，包含了Amazon alexa系列的所有產品
3. 蒐集而來的資料型態為何
    包含數字型以及文字型資料
4. 這組資料想解決的問題如何評估
    由用戶reviews可以成為改善amazon alexa AI功能，例如新增語言學習資料庫，簡化關鍵字讓幼童也能使用等等。可以先初步將reviews以關鍵字分類，正面或負面reviews，ratings分數
把評論以分數加權量化，再由分數分布對應各類細項找出相關性得知最容易影響客戶的因素是甚麼，進而改善產品功能

作業2：

想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
    假設車隊的客源尚未飽和，還有潛在未開發市場，加上同業競爭對手擁有穩定客源，可以透過用戶評價或從客戶使用習慣得知於其他競爭對手業績以及客戶選擇其他同業的原因，分析改善後(例如加強宣傳車隊，app使用介面優化，支付功能改善等等)
    還能提升多少業績，比較目前和預估能提升業績的差異，就是目前還能進步的空間。

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
    可以從客戶要求需要載客到上車時間，價格，服務評價等等因素比較於競爭對手的優缺點。也可以從客戶叫車頻率分析出熱門地點，以便及時供應車子。資料可以從app的使用紀錄裡跟服務評價蒐集
    
3. 蒐集而來的資料型態為何
    數字型：上車時間、價格
    文字型：服務評價
4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
    若是屬於數字型的資料，可以直接量化比較；若是文字型的資料，則需要先做rating將用戶評價給分，可以從關鍵字分類做加權給分(例如:遲到屬於時間項目-2, 態度不佳屬於服務項目-1)，分析需要改善的部分
